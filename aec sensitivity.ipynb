# %% [markdown]
# # sensitivity

# %%
def getInterpZoneData(CCT_Comp, comFactor, CCT, maxCC):
    pass

# %%
CCTBasedExpComp = [['6500K', 1.02], ['5000K', 1], ['4500K', 0.97], ['4200K', 1.03], ['3200K', 1.04], ['2600K', 1.12]]

import math
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111)

(x, y) = zip(*CCTBasedExpComp) 
print x,y
plt.plot(x, y, 'b--o')
    
plt.xlabel('CCT')
plt.ylabel('Ratio')
plt.title('CCT based Exp Comp')
plt.show()
# Out:
# ('6500K', '5000K', '4500K', '4200K', '3200K', '2600K') (1.02, 1, 0.97, 1.03, 1.04, 1.12)
